# %%
import cv2 
import matplotlib.pyplot as plt

# %%
img = cv2.imread('E:\\Wallpapers\\1.jpg')

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
cv2.imwrite('E:\\Wallpapers\\1.jpg', img)
# Out:
# True

# %%
cv2.imshow('ouptputwindow', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
pix= img[100,100]

# %%
print(pix)
# Out:
# [69 99 88]

# %%
img[200,200] = [0,0,255]

# %%
img2 = cv2.imread('E:\\Wallpapers\\2.jpg')

# %%
plt.imshow(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB))

# %%
pix = img2[10,10]

# %%
print(pix)
# Out:
# [255   0   0]

# %%
img2[10,10] = [0,0,255]

# %%
img2 = cv2.imread('E:\\Wallpapers\\2.jpg')

# %%
print(img.shape)
# Out:
# (2812, 5000, 3)

# %%
print(img.size)
# Out:
# 42180000

# %%
print(img.dtype)
# Out:
# uint8

# %%
b,g,r = cv2.split(img)

# %%
_, bmod = cv2.threshold(b,100,255,cv2.THRESH_BINARY)

# %%
merged = cv2.merge((bmod,g,r))

# %%
cv2.imshow('ouptputwindow', merged)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
resized = cv2.resize(img,(200,200))

# %%
cv2.imshow('ouptputwindow', resized)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
rotated = cv2.rotate(img,cv2.ROTATE_90_CLOCKWISE)

# %%
cv2.imshow('ouptputwindow', rotated)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
cv2.circle(img,(100,100),75,(0,255,0))
# Out:
# array([[[ 93, 140, 118],
#         [ 93, 140, 118],
#         [ 93, 140, 118],
#         ...,
#         [ 46,  88,  87],
#         [ 47,  89,  88],
#         [ 47,  89,  88]],
#
#        [[ 96, 143, 121],
#         [ 96, 143, 121],
#         [ 96, 143, 121],
#         ...,
#         [ 47,  89,  88],
#         [ 47,  89,  88],
#         [ 48,  90,  89]],
#
#        [[100, 147, 125],
#         [100, 147, 125],
#         [ 99, 146, 124],
#         ...,
#         [ 48,  90,  89],
#         [ 49,  91,  90],
#         [ 49,  91,  90]],
#
#        ...,
#
#        [[ 32,  40,  39],
#         [ 32,  40,  39],
#         [ 32,  40,  39],
#         ...,
#         [170, 185, 201],
#         [169, 184, 200],
#         [168, 183, 199]],
#
#        [[ 32,  40,  39],
#         [ 32,  40,  39],
#         [ 32,  40,  39],
#         ...,
#         [173, 188, 204],
#         [172, 187, 203],
#         [171, 186, 202]],
#
#        [[ 32,  40,  39],
#         [ 32,  40,  39],
#         [ 32,  40,  39],
# ...

# %%
cv2.imshow('ouptputwindow', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
cv2.rectangle(img,(100,100),(300,300),(0,255,0),1)
# Out:
# array([[[ 93, 140, 118],
#         [ 93, 140, 118],
#         [ 93, 140, 118],
#         ...,
#         [ 46,  88,  87],
#         [ 47,  89,  88],
#         [ 47,  89,  88]],
#
#        [[ 96, 143, 121],
#         [ 96, 143, 121],
#         [ 96, 143, 121],
#         ...,
#         [ 47,  89,  88],
#         [ 47,  89,  88],
#         [ 48,  90,  89]],
#
#        [[100, 147, 125],
#         [100, 147, 125],
#         [ 99, 146, 124],
#         ...,
#         [ 48,  90,  89],
#         [ 49,  91,  90],
#         [ 49,  91,  90]],
#
#        ...,
#
#        [[ 32,  40,  39],
#         [ 32,  40,  39],
#         [ 32,  40,  39],
#         ...,
#         [170, 185, 201],
#         [169, 184, 200],
#         [168, 183, 199]],
#
#        [[ 32,  40,  39],
#         [ 32,  40,  39],
#         [ 32,  40,  39],
#         ...,
#         [173, 188, 204],
#         [172, 187, 203],
#         [171, 186, 202]],
#
#        [[ 32,  40,  39],
#         [ 32,  40,  39],
#         [ 32,  40,  39],
# ...

# %%
cv2.imshow('ouptputwindow', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
cv2.putText(img, "Hello", (100,100), cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255))
# Out:
# array([[[ 93, 140, 118],
#         [ 93, 140, 118],
#         [ 93, 140, 118],
#         ...,
#         [ 46,  88,  87],
#         [ 47,  89,  88],
#         [ 47,  89,  88]],
#
#        [[ 96, 143, 121],
#         [ 96, 143, 121],
#         [ 96, 143, 121],
#         ...,
#         [ 47,  89,  88],
#         [ 47,  89,  88],
#         [ 48,  90,  89]],
#
#        [[100, 147, 125],
#         [100, 147, 125],
#         [ 99, 146, 124],
#         ...,
#         [ 48,  90,  89],
#         [ 49,  91,  90],
#         [ 49,  91,  90]],
#
#        ...,
#
#        [[ 32,  40,  39],
#         [ 32,  40,  39],
#         [ 32,  40,  39],
#         ...,
#         [170, 185, 201],
#         [169, 184, 200],
#         [168, 183, 199]],
#
#        [[ 32,  40,  39],
#         [ 32,  40,  39],
#         [ 32,  40,  39],
#         ...,
#         [173, 188, 204],
#         [172, 187, 203],
#         [171, 186, 202]],
#
#        [[ 32,  40,  39],
#         [ 32,  40,  39],
#         [ 32,  40,  39],
# ...

# %%
cv2.imshow('ouptputwindow', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
imggray = cv2.imread('E:\\Wallpapers\\1.jpg',0)

# %%
cv2.imshow('ouptputwindow', imggray)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
)binaryimg = cv2.threshold(imggray,100,255,cv2.THRESH_BINARY)

# %%
cv2.imshow('ouptputwindow', binaryimg)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 cv2.imshow('ouptputwindow', binaryimg)
#       2 cv2.waitKey()
#       3 cv2.destroyAllWindows()
#
# error: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'imshow'
# > Overload resolution failed:
# >  - mat is not a numerical tuple
# >  - Expected Ptr<cv::cuda::GpuMat> for argument 'mat'
# >  - Expected Ptr<cv::UMat> for argument 'mat'
